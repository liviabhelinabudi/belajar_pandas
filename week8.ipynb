# %% [markdown]
# Materi 29: Melakukan random sampling pada Data Frame

# %% [markdown]
# Import Modules

# %%
import pandas as pd

print(pd.__version__)
# Out:
# 2.3.3

# %% [markdown]
# Persiapan Data Frame

# %%
d = {'col_1':[1, 2, 3, 4, 5], 
     'col_2':[10, 20, 30, 40, 50]}
df = pd.DataFrame(d)
df
# Out:
#    col_1  col_2
# 0      1     10
# 1      2     20
# 2      3     30
# 3      4     40
# 4      5     50

# %% [markdown]
# Random sampling with or without replacement

# %%
df.sample(n=4, replace=False, random_state=0)
# Out:
#    col_1  col_2
# 2      3     30
# 0      1     10
# 1      2     20
# 3      4     40

# %%
df.sample(n=4, replace=True, random_state=0)
# Out:
#    col_1  col_2
# 4      5     50
# 0      1     10
# 3      4     40
# 3      4     40

# %% [markdown]
# Materi 30: Akses nilai variabel pada query()

# %% [markdown]
# Import Modules

# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 2.3.3
# 2.3.5

# %% [markdown]
# Persiapan Data Frame

# %%
n_rows = 5
n_cols = 5
cols = tuple('ABCDE')

df = pd.DataFrame(np.random.randint(1, 20, size=(n_rows, n_cols)), 
                  columns=cols)
df
# Out:
#     A   B   C   D   E
# 0  14   5  11  16   1
# 1   6   3   1   5   6
# 2  10   1  16  19  10
# 3  10   9  10   8  19
# 4   7  17  11   8  19

# %% [markdown]
# Akses nilai variabel pada query()

# %%
df.query('A > 10')
# Out:
#     A  B   C   D  E
# 0  14  5  11  16  1

# %%
rerata = df['A'].mean()
rerata
# Out:
# np.float64(9.4)

# %%
df.query('A > @rerata')
# Out:
#     A  B   C   D   E
# 0  14  5  11  16   1
# 2  10  1  16  19  10
# 3  10  9  10   8  19

# %% [markdown]
# Materi 31: Mengenal tipe data Ordinal pada Pandas

# %% [markdown]
# Import Modules

# %%
import pandas as pd

print(pd.__version__)
# Out:
# 2.3.3

# %% [markdown]
# Persiapan Data Frame

# %%
d = {'pelanggan':[11, 12, 13, 14], 
     'kepuasan':['baik', 'cukup', 'buruk', 'cukup']}

df = pd.DataFrame(d)
df
# Out:
#    pelanggan kepuasan
# 0         11     baik
# 1         12    cukup
# 2         13    buruk
# 3         14    cukup

# %% [markdown]
# Tipe data ordinal pada Pandas

# %%
from pandas.api.types import CategoricalDtype

tingkat_kepuasan = CategoricalDtype(['buruk', 'cukup', 'baik', 'sangat baik'], 
                                    ordered=True)

df['kepuasan'] = df['kepuasan'].astype(tingkat_kepuasan)
df
# Out:
#    pelanggan kepuasan
# 0         11     baik
# 1         12    cukup
# 2         13    buruk
# 3         14    cukup

# %%
df = df.sort_values('kepuasan', ascending=True)
df
# Out:
#    pelanggan kepuasan
# 2         13    buruk
# 1         12    cukup
# 3         14    cukup
# 0         11     baik

# %%
df[df['kepuasan'] >= 'cukup']
# Out:
#    pelanggan kepuasan
# 1         12    cukup
# 3         14    cukup
# 0         11     baik

# %% [markdown]
# Materi 32: Plotting dari suatu Pandas Data Frame

# %% [markdown]
# Import Modules

# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 2.3.3
# 2.3.5

# %% [markdown]
# Persiapan Data Frame

# %%
n_rows = 40
n_cols = 5
cols = tuple('ABCDE')

df = pd.DataFrame(np.random.randint(1, 20, size=(n_rows, n_cols)), 
                  columns=cols)
df.head()
# Out:
#     A   B   C   D   E
# 0  17   8   1  16   5
# 1   7  14   6  13  18
# 2  16   3   8   2  19
# 3   7  19  19   9  15
# 4  14  11   5  14   6

# %% [markdown]
# Line Plot

# %%
df.head()
# Out:
#     A   B   C   D   E
# 0  17   8   1  16   5
# 1   7  14   6  13  18
# 2  16   3   8   2  19
# 3   7  19  19   9  15
# 4  14  11   5  14   6

# %%
df.plot(kind='line')
# Out:
# <Axes: >

# %%
df[['A', 'B']].plot(kind='line')
# Out:
# <Axes: >

# %% [markdown]
# Bar Plot

# %%
df.head()
# Out:
#     A   B   C   D   E
# 0  17   8   1  16   5
# 1   7  14   6  13  18
# 2  16   3   8   2  19
# 3   7  19  19   9  15
# 4  14  11   5  14   6

# %%
df.plot(kind='bar')
# Out:
# <Axes: >

# %%
df[['A', 'B']].plot(kind='bar')
# Out:
# <Axes: >

# %%
df[['A', 'B']].head().plot(kind='bar')
# Out:
# <Axes: >

# %%
df[['A', 'B']].head().plot(kind='barh')
# Out:
# <Axes: >

# %% [markdown]
# Area Plot

# %%
df.head()
# Out:
#     A   B   C   D   E
# 0  17   8   1  16   5
# 1   7  14   6  13  18
# 2  16   3   8   2  19
# 3   7  19  19   9  15
# 4  14  11   5  14   6

# %%
df.plot(kind='area')
# Out:
# <Axes: >

# %%
df[['A', 'B']].head().plot(kind='area')
# Out:
# <Axes: >

# %% [markdown]
# Box Plot

# %%
df.head()
# Out:
#     A   B   C   D   E
# 0  17   8   1  16   5
# 1   7  14   6  13  18
# 2  16   3   8   2  19
# 3   7  19  19   9  15
# 4  14  11   5  14   6

# %%
df.plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# Histogram

# %%
df.head()
# Out:
#     A   B   C   D   E
# 0  17   8   1  16   5
# 1   7  14   6  13  18
# 2  16   3   8   2  19
# 3   7  19  19   9  15
# 4  14  11   5  14   6

# %%
df.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df[['A', 'B']].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# Kernel Density Estimation (KDE)

# %%
df.head()
# Out:
#     A   B   C   D   E
# 0  17   8   1  16   5
# 1   7  14   6  13  18
# 2  16   3   8   2  19
# 3   7  19  19   9  15
# 4  14  11   5  14   6

# %%
df.plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# Scatter Plot

# %%
df.head()
# Out:
#     A   B   C   D   E
# 0  17   8   1  16   5
# 1   7  14   6  13  18
# 2  16   3   8   2  19
# 3   7  19  19   9  15
# 4  14  11   5  14   6

# %%
df.plot(x='A', y='B', kind='scatter')
# Out:
# <Axes: xlabel='A', ylabel='B'>
