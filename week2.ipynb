# %% [markdown]
# Materi 5:  Membalik Urutan Baris dan Kolom pada Data Frame

# %% [markdown]
# Import Modules

# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 2.3.3
# 2.3.5

# %% [markdown]
# Persiapan Data Frame

# %%
n_rows = 5
n_cols = 5
cols = tuple('ABCDE')

df = pd.DataFrame(np.random.randint(1, 10, size=(n_rows, n_cols)), 
                  columns=cols)
df
# Out:
#    A  B  C  D  E
# 0  9  4  7  7  9
# 1  1  4  8  6  1
# 2  3  1  1  3  2
# 3  8  8  3  6  3
# 4  7  2  3  4  9

# %% [markdown]
# Membalik Urutan Kolom

# %%
df.loc[:, ::-1]
# Out:
#    E  D  C  B  A
# 0  9  7  7  4  9
# 1  1  6  8  4  1
# 2  2  3  1  1  3
# 3  3  6  3  8  8
# 4  9  4  3  2  7

# %% [markdown]
# Membalik Urutan Baris

# %%
df.loc[::-1]
# Out:
#    A  B  C  D  E
# 4  7  2  3  4  9
# 3  8  8  3  6  3
# 2  3  1  1  3  2
# 1  1  4  8  6  1
# 0  9  4  7  7  9

# %% [markdown]
# Membalik Urutan Baris dan Melakukan Penyesuaian Ulang index

# %%
df.loc[::-1].reset_index(drop=True)
# Out:
#    A  B  C  D  E
# 0  7  2  3  4  9
# 1  8  8  3  6  3
# 2  3  1  1  3  2
# 3  1  4  8  6  1
# 4  9  4  7  7  9

# %% [markdown]
# Materi 6: Mengganti nama (label) kolom pada Data Frame

# %% [markdown]
# Import Modules

# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 2.3.3
# 2.3.5

# %% [markdown]
# Persiapan Data Frame

# %%
n_rows = 5
n_cols = 5
cols = tuple('ABCDE')

df = pd.DataFrame(np.random.randint(1, 10, size=(n_rows, n_cols)), 
                  columns=cols)
df
# Out:
#    A  B  C  D  E
# 0  3  2  1  1  2
# 1  5  9  1  4  4
# 2  9  6  9  5  7
# 3  8  8  4  2  9
# 4  9  2  2  9  8

# %% [markdown]
# Mengganti nama (label) untuk sebuah kolom pada Data Frame

# %%
df.rename(columns={'C':'Hobi'})
# Out:
#    A  B  Hobi  D  E
# 0  3  2     1  1  2
# 1  5  9     1  4  4
# 2  9  6     9  5  7
# 3  8  8     4  2  9
# 4  9  2     2  9  8

# %% [markdown]
# Mengganti nama (label) untuk banyak kolom pada Data Frame

# %%
df.rename(columns={'A':'Nama', 'B':'Alamat', 'D':'Kota'})
# Out:
#    Nama  Alamat  C  Kota  E
# 0     3       2  1     1  2
# 1     5       9  1     4  4
# 2     9       6  9     5  7
# 3     8       8  4     2  9
# 4     9       2  2     9  8

# %% [markdown]
# Materi 7: Menghapus (drop) missing values (NaN)

# %% [markdown]
# Import Modules

# %%
import pandas as pd

print(pd.__version__)
# Out:
# 2.3.3

# %% [markdown]
# Persiapan Data Frame

# %%
n_rows = 30
n_cols = 4
cols = ['A', 'B', 'C', 'D']

df = pd.DataFrame(np.random.randn(n_rows, n_cols), columns=cols)

nan_mask = np.random.rand(n_rows, n_cols) < 0.2
df[nan_mask] = np.nan

df = df.reset_index()
df.head()
# Out:
#    index         A         B         C         D
# 0      0 -1.109115 -0.381235  1.249274  0.045039
# 1      1 -0.661328 -1.800701  1.942421 -0.678767
# 2      2 -0.534176 -0.191864 -1.765357 -0.689288
# 3      3 -0.595975 -0.778520 -1.400566 -2.130268
# 4      4 -1.532655  0.890855 -0.283847 -0.796222

# %%
df = df.rename(columns={'index':'Z'})
df.head()
# Out:
#    Z         A         B         C         D
# 0  0 -1.109115 -0.381235  1.249274  0.045039
# 1  1 -0.661328 -1.800701  1.942421 -0.678767
# 2  2 -0.534176 -0.191864 -1.765357 -0.689288
# 3  3 -0.595975 -0.778520 -1.400566 -2.130268
# 4  4 -1.532655  0.890855 -0.283847 -0.796222

# %%
df_backup = df.copy(deep=True)

# %% [markdown]
# Menghapus (drop) setiap kolom yang mengandung missing values

# %%
df = df.dropna(axis='columns') 
df.head()
# Out:
#    Z
# 0  0
# 1  1
# 2  2
# 3  3
# 4  4

# %% [markdown]
# Menghapus (drop) setiap baris yang mengandung missing values

# %%
df = df_backup.copy(deep=True)
df = df.dropna(axis='rows')
df.head()
# Out:
#    Z         A         B         C         D
# 0  0 -1.109115 -0.381235  1.249274  0.045039
# 1  1 -0.661328 -1.800701  1.942421 -0.678767
# 2  2 -0.534176 -0.191864 -1.765357 -0.689288
# 3  3 -0.595975 -0.778520 -1.400566 -2.130268
# 4  4 -1.532655  0.890855 -0.283847 -0.796222

# %% [markdown]
# Persentase missing values untuk setiap kolom

# %%
df = df_backup.copy(deep=True)
df.isna().mean()
# Out:
# Z    0.000000
# A    0.266667
# B    0.200000
# C    0.166667
# D    0.100000
# dtype: float64

# %% [markdown]
# Menghapus (drop) setiap kolom yang mengandung missing values berdasarkan threshold

# %%
treshold = len(df) * 0.9
df = df.dropna(thresh=treshold, axis='columns')
df.head()
# Out:
#    Z         D
# 0  0  0.045039
# 1  1 -0.678767
# 2  2 -0.689288
# 3  3 -2.130268
# 4  4 -0.796222

# %% [markdown]
# Materi 8: Memeriksa kesamaan antar dua buah kolom (Series) pada Data Frame

# %% [markdown]
# Import Modules

# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 2.3.3
# 2.3.5

# %% [markdown]
# Persiapan Data Frame

# %%
data = {'A':[15, 15, 18, np.nan, 12], 
        'B':[15, 15, 18, np.nan, 12]}

df = pd.DataFrame(data)
df
# Out:
#       A     B
# 0  15.0  15.0
# 1  15.0  15.0
# 2  18.0  18.0
# 3   NaN   NaN
# 4  12.0  12.0

# %% [markdown]
# Mengenal Pandas Series

# %%
df['A']
# Out:
# 0    15.0
# 1    15.0
# 2    18.0
# 3     NaN
# 4    12.0
# Name: A, dtype: float64

# %%
type(df['A'])
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Memeriksa kesamaan dengan operator ==

# %%
df['A'] == df['B']
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4     True
# dtype: bool

# %% [markdown]
# Memeriksa kesamaan dengan method equals()

# %%
df['A'].equals(df['B'])
# Out:
# True

# %% [markdown]
# Memeriksa kesamaan antar dua Data Frame

# %%
df1 = df.copy(deep=True)

df.equals(df1)
# Out:
# True

# %%
df == df1
# Out:
#        A      B
# 0   True   True
# 1   True   True
# 2   True   True
# 3  False  False
# 4   True   True
